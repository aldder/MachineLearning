# %% [markdown]
# ## Predict model Day Ahead France Energy Price

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from bokeh.models import ColumnDataSource, HoverTool, RangeTool
from bokeh.plotting import figure, show, output_notebook
from bokeh.layouts import gridplot, column
output_notebook()
tools = ['xpan','xwheel_zoom','box_zoom','reset','save']

from tqdm import tqdm_notebook

import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline

pd.options.display.max_rows = 10
pd.options.display.max_columns = None
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="8207">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ### PCA

# %% [markdown]
# We can start modeling our problem, let start with pca to reduce the dataset dimensionality

# %%
dataset = pd.read_pickle('data/dataset_eda.pkl')

# %%
dataset = dataset.resample('d').mean().dropna()
dataset.shape
# Out:
# (1441, 131)

# %%
X = dataset.drop(['Y'],1).astype(np.float64)
y = dataset['Y']

from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(-1,1))
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.decomposition import PCA

pca = PCA().fit(X_scaled)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance')
# Out:
# Text(0, 0.5, 'cumulative explained variance')

# %% [markdown]
# We can choose 85 component that represents close to 100% of explained variance

# %%
N_COMPONENTS = 85

X_pca = PCA(n_components=N_COMPONENTS).fit_transform(X_scaled)

X_pca = pd.DataFrame(X_pca, index=dataset.index, columns=[f'PC_{i+1}' for i in range(N_COMPONENTS)])

# %% [markdown]
# ### Machine Learning Models
#  - Ridge, Lasso, ElasticNet
#  - KNeighbors
#  - RandomForest, ExtraTrees, AdaBoost
#  - SVR
#  - Xgboost, LightGBM
#  - MLP

# %%
from sklearn.linear_model import Ridge, Lasso, ElasticNet
from sklearn.neural_network import MLPRegressor
from sklearn.ensemble import AdaBoostRegressor, RandomForestRegressor, ExtraTreesRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor

from sklearn.pipeline import Pipeline
from sklearn.model_selection import TimeSeriesSplit, cross_val_score, cross_val_predict
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

def smape(y_true, y_pred):
    out = 0
    for i in range(y_true.shape[0]):
        a = y_true[i]
        b = y_pred[i]
        c = abs(a)+abs(b)
        if c == 0:
            continue
        out += abs(a - b) / c
    out *= (100.0 / y_true.shape[0])
    return out

# %%
def eval_model(model, cv, X, y):
    predictions = pd.DataFrame(index = X.index, columns=['true','train_pred','test_pred'])
    predictions['true'] = y
    X, y = X.values, y.values
#     for train_idx, test_idx in tqdm_notebook(cv.split(X, y), total=cv.n_splits, 
#                                              desc='Cross-Validation', leave=False):
    for train_idx, test_idx in cv.split(X, y):
        X_train, y_train = X[train_idx], y[train_idx]
        X_test, y_test = X[test_idx], y[test_idx]

        X_scaler = MinMaxScaler(feature_range=(-1,1))
        X_train = X_scaler.fit_transform(X_train)
        X_test = X_scaler.transform(X_test)

        y_scaler = MinMaxScaler(feature_range=(-1,1))
        y_train = y_scaler.fit_transform(y_train.reshape(-1,1))
        y_test = y_scaler.transform(y_test.reshape(-1,1))
        
        model.fit(X_train, y_train.ravel())
        
        predictions.iloc[train_idx, 1] = y_scaler.inverse_transform(model.predict(X_train).reshape(-1,1))
        predictions.iloc[test_idx, 2] = y_scaler.inverse_transform(model.predict(X_test).reshape(-1,1))

    return predictions.astype(np.float64)

# %%
def eval_predictions(predictions, view=True):
    df_train = predictions[['true','train_pred']].copy().dropna()
    df_test = predictions[['true','test_pred']].copy().dropna()
    print(f"R2 Score Train:  {r2_score(df_train['true'], df_train['train_pred']):.3f}")
    print(f"R2 Score Test:   {r2_score(df_test['true'], df_test['test_pred']):.3f}")
    print(f"MSE Train:       {mean_squared_error(df_train['true'], df_train['train_pred']):.3f}")
    print(f"MSE Test:        {mean_squared_error(df_test['true'], df_test['test_pred']):.3f}")
    print(f"RMSE Train:      {np.sqrt(mean_squared_error(df_train['true'], df_train['train_pred'])):.3f}")
    print(f"RMSE Test:       {np.sqrt(mean_squared_error(df_test['true'], df_test['test_pred'])):.3f}")
    print(f"MAE Train:       {mean_absolute_error(df_train['true'], df_train['train_pred']):.3f}")
    print(f"MAE Test:        {mean_absolute_error(df_test['true'], df_test['test_pred']):.3f}")
    print(f"sMAPE Train:     {smape(df_train['true'], df_train['train_pred']):.3f}")
    print(f"sMAPE Test:      {smape(df_test['true'], df_test['test_pred']):.3f}")
    
    if view:
        fig, ax = plt.subplots(3,2,figsize=(10,8))

        ax[0,0].scatter(df_train['true'], df_train['true']-df_train['train_pred'], alpha=.2, edgecolor='white', label='train_res')
        ax[0,0].scatter(df_test['true'], df_test['true']-df_test['test_pred'], alpha=.2, edgecolor='white', label='test_res')
        ax[0,0].hlines(y=0, colors='r', xmin=min([df_train['true'].min(), df_test['true'].min()]), xmax=max([df_train['true'].max(), df_test['true'].max()]))
        ax[0,0].set_title('Residuals Plot');ax[0,0].set_xlabel('True');ax[0,0].set_ylabel('Residuals')
        ax[0,0].legend()

        sns.regplot(df_train['true'], df_train['train_pred'], label='train reg', scatter_kws={'alpha':.8, 'edgecolor':'white'}, line_kws={'alpha':.5, 'color':'red'}, ax=ax[0,1])
        sns.regplot(df_test['true'], df_test['test_pred'], label='test reg', scatter_kws={'alpha':.8, 'edgecolor':'white'}, line_kws={'alpha':.5, 'color':'red'}, ax=ax[0,1])
        ax[0,1].set_title('Regression Plot');ax[0,1].set_xlabel('True');ax[0,1].set_ylabel('Prediction')
        ax[0,1].legend()

        ax[1,0].hist(df_train['true']-df_train['train_pred'], bins=50, alpha=.4, edgecolor='black',label='train')
        ax[1,0].hist(df_test['true']-df_test['test_pred'], bins=50, alpha=.4, edgecolor='black',label='test')
        ax[1,0].set_title('Residuals distribution');ax[1,0].set_xlabel('Residuals');ax[1,0].set_ylabel('Distribution')
        ax[1,0].legend()

        sns.kdeplot(df_train['true']-df_train['train_pred'], shade=True, ax=ax[1,1], label='train')
        sns.kdeplot(df_test['true']-df_test['test_pred'], shade=True, ax=ax[1,1], label='test')
        ax[1,1].set_title('Residuals density distribution');ax[1,1].set_xlabel('Residuals');ax[1,1].set_ylabel('Density')
        
        sns.barplot(x=df_test.index.weekday, y=np.abs(df_test['true']-df_test['test_pred']), linewidth=2, ax=ax[2,0], edgecolor='black')
        ax[2,0].set_title('MAE by weekday on test data');ax[2,0].set_xlabel('Weekday');ax[2,0].set_ylabel('MAE')

        sns.barplot(x=df_test.index.month, y=np.abs(df_test['true']-df_test['test_pred']), linewidth=2, ax=ax[2,1], edgecolor='black')
        ax[2,1].set_ylim(0,10)
        ax[2,1].set_title('MAE by month on test data');ax[2,1].set_xlabel('Month');ax[2,1].set_ylabel('MAE')

        plt.tight_layout()
        plt.show()
          
        source = ColumnDataSource(data=predictions.reset_index())
        fig = figure(plot_width=700, plot_height=300, x_axis_label='datetime', y_axis_label='price €',
                     x_range=(predictions.index.min(), predictions.index.max()),
                     x_axis_type='datetime', tools=tools)
        g1 = fig.line(x='index', y='true', source=source, legend='True Value')
        g2 = fig.line(x='index', y='train_pred', source=source, legend='Train Pred', line_color='green')
        g3 = fig.line(x='index', y='test_pred', source=source, legend='Test Pred', line_color='darkorange')

        ht = HoverTool(
            renderers=[g1],
            tooltips=[('datetime', '@index{%Y-%m-%d %H:%M}'), ('true', '@true{0.2f} €'),
                      ('train pred', '@train_pred{0.2f} €'), ('test pred', '@test_pred{0.2f} €')],
            formatters={'index': 'datetime'},
            mode='vline'
        )
        fig.add_tools(ht)

        range_tool = RangeTool(x_range=fig.x_range)
        range_tool.overlay.fill_color = "navy"
        range_tool.overlay.fill_alpha = 0.2

        nav = figure(plot_height=90, plot_width=700, y_range=fig.y_range, x_axis_type='datetime',
                     toolbar_location=None, background_fill_color='#efefef')
        nav.line('index', 'true', source=source)
        nav.add_tools(range_tool)
        nav.toolbar.active_multi = range_tool

        show(column(fig, nav))
    return

# %%
model1 = ('Ridge', Ridge(random_state=33))
model2 = ('Lasso', Lasso(random_state=33))
model3 = ('ElasticNet', ElasticNet(random_state=33))
model4 = ('KNeighbors', KNeighborsRegressor(n_jobs=-1))
model5 = ('RandomForest', RandomForestRegressor(criterion='mae', n_jobs=-1, random_state=33))
model6 = ('ExtraTrees', ExtraTreesRegressor(criterion='mae', n_jobs=-1, random_state=33))
model7 = ('AdaBoost', AdaBoostRegressor(random_state=33))
model8 = ('SVR', SVR())
model9 = ('XGBoost', XGBRegressor(n_jobs=-1, random_state=33, silent=False))
model10 = ('LightGBM', LGBMRegressor(n_jobs=-1, random_state=33, silent=False))
model11 = ('MLP', MLPRegressor(random_state=33, verbose=1))

models = [model1, model2, model3, model4, model5, model6, model7, model8, 
          model9, model10, model11]

tscv = TimeSeriesSplit(n_splits=5)
scaler = MinMaxScaler(feature_range=(-1,1))

score_df = pd.DataFrame(index=range(tscv.n_splits), 
                        columns=[mod[0] for mod in models])

for i, model in tqdm_notebook(enumerate(models), total=len(models)):
    pipe = Pipeline([('scaler',scaler), ('model',model[1])])
    print('MODEL: ', model[0])
    scores = cross_val_score(pipe, X_pca, y, scoring='neg_mean_absolute_error', cv=tscv, n_jobs=-1
                            )
    print('SCORE: ', np.mean(np.abs(scores)))
    for n in range(5):
        score_df.iloc[n, i] = abs(scores[n])

score_df
# Out:
# ...
# MODEL:  Ridge
# SCORE:  5.992332259146046
# MODEL:  Lasso
# SCORE:  11.860755059304143
# MODEL:  ElasticNet
# SCORE:  11.831146577978663
# MODEL:  KNeighbors
# SCORE:  11.637841847386913
# MODEL:  RandomForest
# SCORE:  12.214887834321475
# MODEL:  ExtraTrees
# SCORE:  11.87564951645806
# MODEL:  AdaBoost
# SCORE:  10.820706531271178
# MODEL:  SVR
# SCORE:  12.240348057466994
# MODEL:  XGBoost
# SCORE:  10.692928986219357
# MODEL:  LightGBM
# SCORE:  11.148731287887802
# MODEL:  MLP
# SCORE:  12.732752343011544
#      Ridge    Lasso ElasticNet KNeighbors RandomForest ExtraTrees AdaBoost  \
# 0  10.3375  10.6365    10.1135    10.1944      12.5706    10.8576  10.5482
# 1  5.40997  12.4584    12.4857    10.7833      12.0163    12.2565  11.8231
# 2  4.26619  7.33181    8.28895    7.74556      8.24338    9.02436   7.6421
# 3  4.98874  9.19069    10.7954    10.0488      9.04793    8.74305  7.60891
# 4  4.95926  19.6864    17.4722    19.4171      19.1962    18.4967  16.4813
#
# ...

# %%
for c in score_df.columns:
    print(f'{c} test mae: {score_df[c].mean():.3f} +- {score_df[c].std():.2f}')
# Out:
# Ridge test mae: 5.992 +- 2.46
# Lasso test mae: 11.861 +- 4.76
# ElasticNet test mae: 11.831 +- 3.49
# KNeighbors test mae: 11.638 +- 4.50
# RandomForest test mae: 12.215 +- 4.32
# ExtraTrees test mae: 11.876 +- 3.97
# AdaBoost test mae: 10.821 +- 3.66
# SVR test mae: 12.240 +- 3.59
# XGBoost test mae: 10.693 +- 3.19
# LightGBM test mae: 11.149 +- 3.92
# MLP test mae: 12.733 +- 3.01

# %% [markdown]
# ok, we have some results.
#
# The best model after reducing the dimensionality with PCA is the Ridge.
#
# It's a bit strange the difference with others models, maybe they don't like too much the PCA. What we can do is try to start from the full dataset and make some feature selection. Let's try with XGBoost and see what happends.

# %% [markdown]
# ### XGBoost feature selection

# %% [markdown]
# #### 1. RFECV

# %%
regressor = XGBRegressor(n_jobs=-1, random_state=33)
tscv = TimeSeriesSplit(n_splits=5)
scaler = MinMaxScaler(feature_range=(-1,1))
from sklearn.feature_selection import RFECV
rfecv = RFECV(estimator=regressor, cv=tscv, verbose=0, scoring='neg_mean_absolute_error', n_jobs=-1)
rfecv.fit(X, y)

print(f'Optimal number of features : {rfecv.n_features_}')
features = list(X.columns[rfecv.get_support()])

plt.figure()
plt.xlabel("Number of features selected")
plt.ylabel("Cross validation score (nb of correct classifications)")
plt.plot(range(1, len(rfecv.grid_scores_) + 1), rfecv.grid_scores_)
plt.plot(rfecv.n_features_, max(rfecv.grid_scores_), 'ro')
plt.show()

X_rfe = pd.DataFrame(rfecv.transform(X), index=X.index, columns=features)
# Out:
# Optimal number of features : 10

# %%
regressor = XGBRegressor(n_jobs=-1, random_state=33)
tscv = TimeSeriesSplit(n_splits=5)
scaler = MinMaxScaler(feature_range=(-1,1))
pipe = Pipeline([('scaler',scaler), ('regressor',regressor)])

predictions = eval_model(model=pipe, cv=tscv, X=X_rfe, y=y)

eval_predictions(predictions, view=True)
# Out:
# R2 Score Train:  0.942
# R2 Score Test:   0.786
# MSE Train:       12.531
# MSE Test:        57.242
# RMSE Train:      3.540
# RMSE Test:       7.566
# MAE Train:       2.649
# MAE Test:        5.353
# sMAPE Train:     3.702
# sMAPE Test:      6.645
#   <div class="bk-root" id="e6932adb-6fbb-4592-89ef-a4a2b9d21b1f" data-root-id="5173"></div>

# %% [markdown]
# #### 2. SFM

# %%
regressor = XGBRegressor(n_jobs=-1, random_state=33)
tss = TimeSeriesSplit(n_splits=5)
sfm = SelectFromModel(estimator=regressor, max_features=X.shape[1])
X_sfm = sfm.fit_transform(X, y)
min_err, max_features, X_best, best_support = -np.Inf, -1, X_sfm, sfm.get_support()
scores, n_features = [], []
for n in tqdm_notebook(range(X_sfm.shape[1], 0, -1)):
    sfm.max_features = n
    X_sfm = sfm.transform(X)
    score = np.mean(np.abs(cross_val_score(regressor, X_sfm, y, scoring='neg_mean_absolute_error', cv=tss)))
    scores.append(score)
    n_features.append(n)
    if score < min_err:
        print(f'max_features: {n}, best score: {score}')
        min_err = score
        max_features=n
        X_best = X_sfm.copy()
        best_support = sfm.get_support()

plt.figure()
plt.plot(n_features, scores)
plt.plot(n_features[np.argmin(scores)], min(scores), 'ro')
plt.title('Selected scores for max features')
plt.xlabel('Max Features')
plt.ylabel('Score (mae)')
plt.show()

X_sfm = pd.DataFrame(X_best, columns=X.columns[best_support], index=X.index)

# %%
regressor = XGBRegressor(n_jobs=-1, random_state=33)
tscv = TimeSeriesSplit(n_splits=5)
scaler = MinMaxScaler(feature_range=(-1,1))

pipe = Pipeline([('scaler',scaler), ('regressor',regressor)])

predictions = eval_model(model=regressor, cv=tscv, X=X_sfm, y=y)
eval_predictions(predictions, view=True)
# Out:
# R2 Score Train:  0.948
# R2 Score Test:   0.778
# MSE Train:       11.203
# MSE Test:        59.197
# RMSE Train:      3.347
# RMSE Test:       7.694
# MAE Train:       2.522
# MAE Test:        5.416
# sMAPE Train:     3.534
# sMAPE Test:      6.701
#   <div class="bk-root" id="817d4e1f-0af2-4438-b85c-674aa3fa150f" data-root-id="4477"></div>

# %% [markdown]
# Well, it seems that using XGBoost with recursive feature eliminations performs better than Ridge with PCA.
#
# Let's try to optimize a bit the Ridge regression and see what happends

# %% [markdown]
# ### Ridge optimization

# %%
alpha = np.linspace(0.01, 10.0, 100)
min_error, best_alpha = np.inf, -1
tscv = TimeSeriesSplit(n_splits=5)
scaler = MinMaxScaler(feature_range=(-1,1))

for a in tqdm_notebook(alpha):
    regressor = Ridge(alpha=a, random_state=33)
    pipe = Pipeline([('scaler',scaler), ('regressor',regressor)])
    predictions = eval_model(model=pipe, cv=tscv, X=X_pca, y=y)
    predictions = predictions[['true','test_pred']].dropna()
    loss = mean_absolute_error(predictions['true'], predictions['test_pred'])
    if loss < min_error:
        print(f'best_error: {loss}, best_alpha: {a}')
        min_error = loss
        best_alpha = a
# Out:
# ...
# best_error: 6.286946525560102, best_alpha: 0.01
# best_error: 5.842382080590442, best_alpha: 0.1109090909090909

# %%
regressor = Ridge(alpha=0.111, random_state=33)
tscv = TimeSeriesSplit(n_splits=5)
scaler = MinMaxScaler(feature_range=(-1,1))
pipe = Pipeline([('scaler',scaler), ('regressor',regressor)])

predictions = eval_model(model=pipe, cv=tscv, X=X_pca, y=y)

eval_predictions(predictions, view=True)
# Out:
# R2 Score Train:  0.888
# R2 Score Test:   0.767
# MSE Train:       24.359
# MSE Test:        62.182
# RMSE Train:      4.935
# RMSE Test:       7.886
# MAE Train:       3.689
# MAE Test:        5.842
# sMAPE Train:     5.059
# sMAPE Test:      7.780
#   <div class="bk-root" id="b37e42d2-6bf0-4d9d-a8d2-637eaad5898b" data-root-id="6688"></div>

# %% [markdown]
# The best error (mae) with Ridge model after hyperoptimization is still higher that XGBoost

# %% [markdown]
# At this point the next thing to do is running hyperparameters optimization on XGBoost.
#
# We won't do that right now, instead i want to show you how to define the steps to implement [Bayesian Search](https://towardsdatascience.com/a-conceptual-explanation-of-bayesian-model-based-hyperparameter-optimization-for-machine-learning-b8172278050f) (instead GridSearch or RandomSearch), to this aim we will use the library [hyperopt](https://github.com/hyperopt/hyperopt) and we will run a very short optimization on a neural network.

# %% [markdown]
# ### MLP Optimization

# %%
from hyperopt import hp, fmin, tpe, STATUS_OK, Trials, space_eval
from hyperopt.pyll.base import scope

tscv = TimeSeriesSplit(n_splits=5)
scaler = MinMaxScaler(feature_range=(-1,1))

space_mlp = {
    'hidden_layer_sizes': scope.int(hp.quniform('hidden_layer_sizes', 10, 200, 1)),
    'activation': hp.choice('activation', ['logistic','relu','tanh']),
    'solver': hp.choice('solver', ['lbfgs','sgd','adam']),
    'learning_rate': hp.choice('learning_rate', ['constant','invscaling','adaptive']),
    'power_t': hp.quniform('power_t', 0.1, 0.9, 0.01),
    'momentum': hp.quniform('momentum', 0, 1, 0.01),
    'beta_1': hp.quniform('beta_1', 0, 1, 0.001),
    'beta_2': hp.quniform('beta_2', 0, 1, 0.001),
    'learning_rate_init': hp.quniform('learning_rate_init', 0.0001, 0.1, 0.0001),
    'alpha': hp.quniform('alpha', 0, 1.0, 0.0001),
}

# Objective Function to minimize
def f_objective(p):

    regressor = MLPRegressor(random_state=33, max_iter=2000, early_stopping=True)
    regressor.set_params(**p)
    
    predictions = eval_model(model=regressor, cv=tscv, X=X_pca, y=y)
    predictions = predictions[['true','test_pred']].dropna()
    loss = mean_absolute_error(predictions['true'], predictions['test_pred'])

    return { 'loss': loss, 'status': STATUS_OK }

trials = Trials()

# Perform evaluations on the search space
best = fmin(fn=f_objective,
            space=space_mlp, 
            algo=tpe.suggest,
            max_evals=10, #use at least 1000 trials with high parameter space
            show_progressbar=True,
            trials=trials)

# best hyperparameters
print("The best hyperparameters:")
print(space_eval(space_mlp, best))
# Out:
# 100%|██████████| 10/10 [00:23<00:00,  2.73s/it, best loss: 6.330593137453983]
# The best hyperparameters:
# {'activation': 'logistic', 'alpha': 0.6581, 'beta_1': 0.267, 'beta_2': 0.18, 'hidden_layer_sizes': 39, 'learning_rate': 'constant', 'learning_rate_init': 0.0218, 'momentum': 0.54, 'power_t': 0.37, 'solver': 'lbfgs'}

# %%
best_params_mlp = {'activation': 'logistic', 'alpha': 0.6581, 'beta_1': 0.267, 'beta_2': 0.18, 
                   'hidden_layer_sizes': 39, 'learning_rate': 'constant', 
                   'learning_rate_init': 0.0218, 'momentum': 0.54, 'power_t': 0.37, 'solver': 'lbfgs'}

regressor = MLPRegressor(random_state=33, max_iter=2000, early_stopping=True)
regressor.set_params(**best_params_mlp)
print(regressor)
tscv = TimeSeriesSplit(n_splits=5)

predictions = eval_model(model=regressor, cv=tscv, X=X_pca, y=y)

eval_predictions(predictions, view=True)
# Out:
# MLPRegressor(activation='logistic', alpha=0.6581, batch_size='auto',
#        beta_1=0.267, beta_2=0.18, early_stopping=True, epsilon=1e-08,
#        hidden_layer_sizes=39, learning_rate='constant',
#        learning_rate_init=0.0218, max_iter=2000, momentum=0.54,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.37,
#        random_state=33, shuffle=True, solver='lbfgs', tol=0.0001,
#        validation_fraction=0.1, verbose=False, warm_start=False)
# R2 Score Train:  0.887
# R2 Score Test:   0.730
# MSE Train:       24.586
# MSE Test:        72.121
# RMSE Train:      4.958
# RMSE Test:       8.492
# MAE Train:       3.677
# MAE Test:        6.331
# sMAPE Train:     5.026
# sMAPE Test:      8.228
#   <div class="bk-root" id="bf395e53-ff79-4c49-b3de-f4fd16782309" data-root-id="8368"></div>

# %% [markdown]
# # Conclusions
#
# We achieved the best result using _XGBoost_ regression, with a mean absolute error on test data equals to __5.35 €__
